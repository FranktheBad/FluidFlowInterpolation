# %% [markdown]
# # Instruction for your homework

# %% [markdown]
# As your first assignment, you will write an article using the "publishing" features that are offered by deepnote notebooks.

# %% [markdown]
# Submission procedure

# %% [markdown]
# - To export your notebook as PDF follow the guide here.  Before exporting the PDF, go to "Setting & members" in your workspace, then "Project settings", and make sure that the options  "Allow projects to be shared publicly"  and "Allow apps to be shared publicly" are both turned on.

# %% [markdown]
# - Once you export the PDF file rename the file using your name. Articles should be submitted using Hippocampus, here. The deadline for submission is 20/12/2024 at 23h59. Please, do not submit your article by email.

# %% [markdown]
# Subject of the article

# %% [markdown]
# You can choose between two subjects:

# %% [markdown]
# - "Runge's phenomenon": Describe what  Runge's phenomenon is and how to get rid of it.

# %% [markdown]
# - "Turbulent flow in a pipe":  Use regression techniques on experimental flow data to predict the turbulent flow in a pipe.

# %% [markdown]
# The second subject is more challenging and has a higher difficulty coefficient.

# %% [markdown]
# Structure of the article

# %% [markdown]
# Regardless of the subject, all articles should contain text, python code blocks, figures and equations (use markdown blocks for that).  In PDF, the python code should also include the output:

# %%
print("just like this")
# Out:
# just like this

# %% [markdown]
# The article should be organized in sections, including : Background/Motivations, Problem Statement, Dataset description (only for the second assignment), Methods, Results, Conclusions and Bibliography.

# %% [markdown]
# You are encouraged to use external sources (Wikipedia is ok...but try to use actual scientific papers too) to enrich the content of your article, but make sure you cite your references properly in the reference section. It's ok to include some historical background in your article.

# %% [markdown]
# For instance, if you want to cite the original paper from Carl Runge [Run01], this is how a proper citation format looks like :

# %% [markdown]
# [Run01] Runge, Carl. "Über empirische Funktionen und die Interpolation zwischen äquidistanten Ordinaten." Zeitschrift für Mathematik und Physik 46.224-243 (1901): 20

# %% [markdown]
# Add all your references at the end of your article in the Bibliography section.

# %% [markdown]
# Author's name should be written on the top of the front page, as well as in the name of the PDF.

# %% [markdown]
# Evaluation criteria

# %% [markdown]
# - Your Python code should provide correct results to the problem in your assignment (50%)

# %% [markdown]
# - Figures, data plots, and equations, must be clear and readable. Check matplotlib gallery to see examples of how to produce good quality plots. Also check how to use markdown to write equations to produce nice latex equations. (10%)

# %% [markdown]
# - The article structure respects the instructions given above (10%)

# %% [markdown]
# - Difficulty Coefficient (0% for Subject 1 , 20% for Subject 2)

# %% [markdown]
# - Originality (5%)

# %% [markdown]
# - Programming "style" (5%).

# %% [markdown]
# This is an example of perfectly functional python code:

# %%
word_list = ["this","is","an","example","of what","orginal","means"]

def remove_vowels_from(this_word):
    vowels = ['a', 'e', 'i', 'o', 'u', 'A', 'E', 'I', 'O', 'U']
    result = ""
    for i in range(len(this_word)):
        if this_word[i] not in vowels:
            result = result + this_word[i]
    return result        

result_list = []
for word in word_list:
    new_item = remove_vowels_from(word)
    result_list.append(new_item)

print(result_list)
# Out:
# ['ths', 's', 'n', 'xmpl', 'f wht', 'rgnl', 'mns']

# %% [markdown]
# The same results can be obtained with a more "pythonic" (but equally functional) code:

# %%
import re
def rem_vowels(this_word):
    return (re.sub("[aeiouAEIOU]","",this_word))

result_list = [rem_vowels(words) for words in word_list]

print(result_list)
# Out:
# ['ths', 's', 'n', 'xmpl', 'f wht', 'rgnl', 'mns']

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=2862c49b-4ca6-4b1c-adad-6d8ae1379427' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
